# %% [markdown]
# <a href="https://colab.research.google.com/github/amd257/COVID-detection-using-CNNs/blob/ModelsTrainedonNewestDataset/ParallelSequentialModel_BinaryClassification_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Compressed Binary Classification Dataset file is stored at: https://www.dropbox.com/s/ode8exmty1i0y5i/binaryclassificationdataset.zip?dl=0
# !wget https://www.dropbox.com/s/ode8exmty1i0y5i/binaryclassificationdataset.zip?dl=0
# Out:
# --2021-03-11 19:06:01--  https://www.dropbox.com/s/ode8exmty1i0y5i/binaryclassificationdataset.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6032:18::a27d:5212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/ode8exmty1i0y5i/binaryclassificationdataset.zip [following]
# --2021-03-11 19:06:01--  https://www.dropbox.com/s/raw/ode8exmty1i0y5i/binaryclassificationdataset.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf22a2f8e41b6f25f5122996f10.dl.dropboxusercontent.com/cd/0/inline/BKflqs2lyKWA7iF2YVi-7DhAa7S2Rq9DlLVyRpm5ahQTZZVycxzClrLdeMHn4d54VTUdwLfs03MjpPGbNdEHzJdDEaqGVVaTu9aJ6a6IZwiHS6-Cay9yyfg-rxcaHrckt33Lm77t6P_5aR5gsND42agR/file# [following]
# --2021-03-11 19:06:02--  https://ucf22a2f8e41b6f25f5122996f10.dl.dropboxusercontent.com/cd/0/inline/BKflqs2lyKWA7iF2YVi-7DhAa7S2Rq9DlLVyRpm5ahQTZZVycxzClrLdeMHn4d54VTUdwLfs03MjpPGbNdEHzJdDEaqGVVaTu9aJ6a6IZwiHS6-Cay9yyfg-rxcaHrckt33Lm77t6P_5aR5gsND42agR/file
# Resolving ucf22a2f8e41b6f25f5122996f10.dl.dropboxusercontent.com (ucf22a2f8e41b6f25f5122996f10.dl.dropboxusercontent.com)... 162.125.82.15, 2620:100:6032:15::a27d:520f
# Connecting to ucf22a2f8e41b6f25f5122996f10.dl.dropboxusercontent.com (ucf22a2f8e41b6f25f5122996f10.dl.dropboxusercontent.com)|162.125.82.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BKdFwd9fNXqvPOI_Xc7EfnooPOR3yYaFA2k3jwpaJcgxdfEE57SyoexPrwdVEkiFJevNshwJufYsSjlCB_UEvHHWsHiog0f5I55bAUKSIyGhUPfM5VnVJ2CITbAQ8soJ_dzI8hDhKe-bDRbXVN1MZl0J2hvRscpOQvzLeQhezeARkeMmyjqcRAzOa2Avrg5szxBVla7KTZI51M7d6c3rb9oJ9ALKhd9-k3KkRZaO6OE9nQl8Mleh9nUl39Y9NfJg4TQ5onlAOiSF1Czr_VjLgfzjcc3FiUnvMOVexLpld2dQFQjqrp0YywregtxcXh__f2z-PAVZP8CdlnHzPDcbrxGIuny_YNMPEmGExGMALOiESOKgG9Lo3pYIj_3eRmDjzZU/file [following]
# --2021-03-11 19:06:02--  https://ucf22a2f8e41b6f25f5122996f10.dl.dropboxusercontent.com/cd/0/inline2/BKdFwd9fNXqvPOI_Xc7EfnooPOR3yYaFA2k3jwpaJcgxdfEE57SyoexPrwdVEkiFJevNshwJufYsSjlCB_UEvHHWsHiog0f5I55bAUKSIyGhUPfM5VnVJ2CITbAQ8soJ_dzI8hDhKe-bDRbXVN1MZl0J2hvRscpOQvzLeQhezeARkeMmyjqcRAzOa2Avrg5szxBVla7KTZI51M7d6c3rb9oJ9ALKhd9-k3KkRZaO6OE9nQl8Mleh9nUl39Y9NfJg4TQ5onlAOiSF1Czr_VjLgfzjcc3FiUnvMOVexLpld2dQFQjqrp0YywregtxcXh__f2z-PAVZP8CdlnHzPDcbrxGIuny_YNMPEmGExGMALOiESOKgG9Lo3pYIj_3eRmDjzZU/file
# Reusing existing connection to ucf22a2f8e41b6f25f5122996f10.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 780517722 (744M) [application/zip]
# Saving to: ‘binaryclassificationdataset.zip?dl=0’
#
# binaryclassificatio 100%[===================>] 744.36M  15.5MB/s    in 55s
#
# 2021-03-11 19:06:58 (13.6 MB/s) - ‘binaryclassificationdataset.zip?dl=0’ saved [780517722/780517722]

# %%
#Extracting the compressed dataset
# !unzip /content/binaryclassificationdataset.zip?dl=0

# %%
#Importing all the libraries required for preprocessing, training and evaluation of the model
from tensorflow import keras
from tensorflow.keras import preprocessing
from tensorflow.keras.preprocessing import image_dataset_from_directory #Importing Functions for image preprocessing from keras
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau #Importing Functions for early stopping and learning rate reduction
from sklearn.utils import class_weight #Importing functions for computing class weights from scikit learn class_weight module
from keras.utils import plot_model
from keras.preprocessing import image
from keras.layers import *
from keras.models import * #Importing the functions required for creating the model
import matplotlib.pyplot as plt #For plotting the training and validation loss and accuracy graphs
import numpy as np
import pandas as pd

# %%
train_images_path = "BinaryClassificationDataset/Train"
validation_images_path = "BinaryClassificationDataset/Validation"
test_images_path = "BinaryClassificationDataset/Test"
image_height = 100
image_width = 100

# %%
#Training data augmentation before feeding it to the CNN model
train_datagen = image.ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,  #flipping will add more variations to the data and it will help fight overfitting as welll
    )

#Preprocessing the training dataset
train_dataset= train_datagen.flow_from_directory(
    train_images_path,
    target_size = (image_height,image_width), 
    batch_size = 32,
    color_mode="grayscale",
    class_mode = "binary", #class mode is binary for binary classification
    shuffle = True,
    seed =50
    )

inp_shape= train_dataset.image_shape
print("Class Labels: ", train_dataset.class_indices)
# Out:
# Found 16930 images belonging to 2 classes.
# Class Labels:  {'COVID': 0, 'Non-COVID': 1}

# %%
validation_datagen = image.ImageDataGenerator(rescale = 1./255) #Rescaling the validation images 

#Preprocessing the validation dataset
validation_dataset = validation_datagen.flow_from_directory(
    validation_images_path,
    target_size = (image_height,image_width),
    batch_size = 32,
    color_mode = "grayscale" ,
    class_mode = "binary",
    shuffle = True,
    seed =40
    )
# Out:
# Found 2116 images belonging to 2 classes.

# %%
test_datagen = image.ImageDataGenerator(rescale = 1./255) #Rescaling the test images 

#Preprocessing the testing dataset
test_dataset = test_datagen.flow_from_directory(
    test_images_path,
    target_size = (image_height,image_width),
    batch_size = 32,
    color_mode = "grayscale" ,
    class_mode = "binary",
    shuffle = True,
    seed =20
    )
# Out:
# Found 1905 images belonging to 2 classes.

# %%
#Visualization of Preprocessed Data
plt.figure(figsize=(20, 10))
for i in range(0, 10):
    plt.subplot(2, 5, i+1)
    for X_batch, Y_batch in train_dataset:
        image = X_batch[0]        
        dic = {0: 'COVID', 1:'Non-COVID'} 
        plt.title(dic.get(Y_batch[0])) #to get index of the image label
        plt.axis('on')
        plt.imshow(np.squeeze(image),cmap='gray',interpolation='nearest')
        break
plt.tight_layout()
plt.show()

# %%
#Creating the parallel sequential model
input_shape = inp_shape
input=Input(shape = input_shape) 
convs=[]
parrallel_kernels=[3,5,7]

for i in range(len(parrallel_kernels)):
  conv = Conv2D(128, parrallel_kernels[i],padding = 'same',activation='relu',input_shape=input_shape,strides=1)(input)
  convs.append(conv)

output = Concatenate()(convs)
conv_model = Model(input,output)

# %%
model = Sequential()
model.add(conv_model) # Added the conv_model with the parallel kernels to the sequential model

model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid')) #sigmoid for binary classification 
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])


model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 100, 100, 384)     11008
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 98, 98, 64)        221248
# _________________________________________________________________
# activation_2 (Activation)    (None, 98, 98, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 47, 47, 32)        18464
# _________________________________________________________________
# activation_3 (Activation)    (None, 47, 47, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16928)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16928)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               2166912
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,425,953
# Trainable params: 2,425,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model,show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True)

# %%
STEP_SIZE_TRAIN=train_dataset.n//train_dataset.batch_size
STEP_SIZE_VALID=validation_dataset.n//validation_dataset.batch_size
print(STEP_SIZE_TRAIN)
print(STEP_SIZE_VALID)
# Out:
# 529
# 66

# %%
#Defining functions for early stopping and adjusting the learning rate during model training 
earlyStop = EarlyStopping(monitor="val_loss", mode="min", patience=5, verbose= 1)
learningRateReduce = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.4, min_lr=0.0000001)
callbacksList = [ earlyStop, learningRateReduce]

# %%
#Assigning class weights using the compute class weights function
classWeights = class_weight.compute_class_weight('balanced', np.unique(train_dataset.classes), train_dataset.classes)
classWeightsDict = dict(enumerate(classWeights))
print("The class weights to be assigned to each label are:", classWeightsDict)
# Out:
# The class weights to be assigned to each label are: {0: 2.927040110650069, 1: 0.6030061262288076}

# %%
hist = model.fit(
    train_dataset, 
    steps_per_epoch = STEP_SIZE_TRAIN, 
    epochs=100,
    validation_data = validation_dataset,
    validation_steps = STEP_SIZE_VALID,
    class_weight = classWeightsDict,
    callbacks=callbacksList
    )
# Out:
# Epoch 1/100
# 529/529 [==============================] - 162s 243ms/step - loss: 0.6908 - accuracy: 0.5648 - val_loss: 0.5966 - val_accuracy: 0.7098
# Epoch 2/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.6616 - accuracy: 0.5853 - val_loss: 0.5317 - val_accuracy: 0.7623
# Epoch 3/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.5999 - accuracy: 0.6726 - val_loss: 0.4225 - val_accuracy: 0.8063
# Epoch 4/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.5343 - accuracy: 0.7203 - val_loss: 0.4053 - val_accuracy: 0.8187
# Epoch 5/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.5000 - accuracy: 0.7449 - val_loss: 0.3857 - val_accuracy: 0.8423
# Epoch 6/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.4646 - accuracy: 0.7626 - val_loss: 0.3128 - val_accuracy: 0.8632
# Epoch 7/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.4662 - accuracy: 0.7611 - val_loss: 0.2797 - val_accuracy: 0.8954
# Epoch 8/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.4541 - accuracy: 0.7732 - val_loss: 0.2619 - val_accuracy: 0.9015
# Epoch 9/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.4295 - accuracy: 0.7825 - val_loss: 0.2821 - val_accuracy: 0.8977
# Epoch 10/100
# 529/529 [==============================] - 127s 239ms/step - loss: 0.4201 - accuracy: 0.7944 - val_loss: 0.2710 - val_accuracy: 0.8944
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# Epoch 11/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3885 - accuracy: 0.8106 - val_loss: 0.2689 - val_accuracy: 0.8954
# Epoch 12/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3772 - accuracy: 0.8192 - val_loss: 0.2355 - val_accuracy: 0.9110
# Epoch 13/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3718 - accuracy: 0.8183 - val_loss: 0.2796 - val_accuracy: 0.8878
# Epoch 14/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3657 - accuracy: 0.8295 - val_loss: 0.2101 - val_accuracy: 0.9309
# Epoch 15/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3486 - accuracy: 0.8439 - val_loss: 0.2118 - val_accuracy: 0.9295
# Epoch 16/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3579 - accuracy: 0.8414 - val_loss: 0.2136 - val_accuracy: 0.9200
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# Epoch 17/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3394 - accuracy: 0.8420 - val_loss: 0.1957 - val_accuracy: 0.9323
# Epoch 18/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3311 - accuracy: 0.8457 - val_loss: 0.1875 - val_accuracy: 0.9337
# Epoch 19/100
# 529/529 [==============================] - 127s 241ms/step - loss: 0.3369 - accuracy: 0.8487 - val_loss: 0.2134 - val_accuracy: 0.9238
# Epoch 20/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3225 - accuracy: 0.8538 - val_loss: 0.1996 - val_accuracy: 0.9290
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# Epoch 21/100
# 529/529 [==============================] - 127s 241ms/step - loss: 0.3208 - accuracy: 0.8520 - val_loss: 0.1930 - val_accuracy: 0.9313
# Epoch 22/100
# 529/529 [==============================] - 127s 241ms/step - loss: 0.3223 - accuracy: 0.8536 - val_loss: 0.1923 - val_accuracy: 0.9290
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# Epoch 23/100
# 529/529 [==============================] - 128s 241ms/step - loss: 0.3093 - accuracy: 0.8588 - val_loss: 0.1821 - val_accuracy: 0.9361
# Epoch 24/100
# 529/529 [==============================] - 128s 241ms/step - loss: 0.3057 - accuracy: 0.8630 - val_loss: 0.1864 - val_accuracy: 0.9342
# Epoch 25/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3083 - accuracy: 0.8626 - val_loss: 0.1837 - val_accuracy: 0.9347
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# Epoch 26/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3122 - accuracy: 0.8633 - val_loss: 0.1792 - val_accuracy: 0.9380
# Epoch 27/100
# 529/529 [==============================] - 127s 241ms/step - loss: 0.3014 - accuracy: 0.8695 - val_loss: 0.1883 - val_accuracy: 0.9328
# Epoch 28/100
# 529/529 [==============================] - 128s 241ms/step - loss: 0.3103 - accuracy: 0.8640 - val_loss: 0.1847 - val_accuracy: 0.9351
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# Epoch 29/100
# 529/529 [==============================] - 128s 241ms/step - loss: 0.3045 - accuracy: 0.8724 - val_loss: 0.1858 - val_accuracy: 0.9337
# Epoch 30/100
# 529/529 [==============================] - 127s 240ms/step - loss: 0.3100 - accuracy: 0.8569 - val_loss: 0.1857 - val_accuracy: 0.9342
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# Epoch 31/100
# 529/529 [==============================] - 128s 241ms/step - loss: 0.2923 - accuracy: 0.8668 - val_loss: 0.1864 - val_accuracy: 0.9337
# Epoch 00031: early stopping

# %%
model.save('ParallelSeqModel_BinaryClassification_Final.h5') #Saving the model
#model = load_model('/content/ParallelSeqModel_BinaryClassification_Final.h5') #for loading the model

# %%
#Plotting the graph for training and validation loss
axes = plt.gca()
#axes.set_xlim([xmin,xmax])
axes.set_ylim([0.1,0.8])
plt.locator_params(axis='x', integer=True, tight=True) #To ensure no. of epochs is shown as integers
plt.plot(hist.history['loss'],'r',label='training loss')
plt.plot(hist.history['val_loss'],label='validation loss')
plt.xlabel('Number of epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Plotting the graph for training and validation accuracy
axes = plt.gca()
#axes.set_xlim([xmin,xmax])
axes.set_ylim([0.5,0.98])
plt.locator_params(axis='x', integer=True, tight=True) 
plt.plot(hist.history['accuracy'],'r',label='training accuracy')
plt.plot(hist.history['val_accuracy'],label='validation accuracy')
plt.xlabel('Number of epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Plotting the graph for learning rate

plt.locator_params(axis='x', integer=True, tight=True) 
plt.plot(hist.history['lr'],label='learning rate')
plt.xlabel('Number of epochs')
plt.ylabel('Learning Rate')
plt.legend()
plt.show()

# %%
testingAccuracy = model.evaluate(test_dataset) #Evaluating the model on the testing dataset
print("The Parallel Sequential Model for binary classification has a testing accuracy of:", testingAccuracy[1]*100, "%")
# Out:
# 60/60 [==============================] - 6s 91ms/step - loss: 0.1680 - accuracy: 0.9386
# The Parallel Sequential Model for binary classification has a testing accuracy of: 93.85826587677002 %
