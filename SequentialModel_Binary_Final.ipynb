# %% [markdown]
# <a href="https://colab.research.google.com/github/amd257/COVID-detection-using-CNNs/blob/FinalRound/SequentialModel_Binary_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Compressed Binary Classification Dataset file is stored at: https://www.dropbox.com/s/dhu2h2me4ccpe9h/BinaryDataset.zip?dl=0
# !wget https://www.dropbox.com/s/dhu2h2me4ccpe9h/BinaryDataset.zip?dl=0
# Out:
# --2021-03-09 15:52:54--  https://www.dropbox.com/s/dhu2h2me4ccpe9h/BinaryDataset.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.82.18, 2620:100:6032:18::a27d:5212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.82.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/dhu2h2me4ccpe9h/BinaryDataset.zip [following]
# --2021-03-09 15:52:54--  https://www.dropbox.com/s/raw/dhu2h2me4ccpe9h/BinaryDataset.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc0e233fc73d9a328f1d83de4e8.dl.dropboxusercontent.com/cd/0/inline/BKUdwBSrDWjwvcwRjmVlC3KBAPcy0u6psPBfhpV6bpigPaODpUcVySVOyoX2zpeFaUqpedj18zYWwze0hy0-k5tbjYaglbHzwo8jP9AIZ7wtbfG0hrxWGa6M0Aj7fgmbnQcnoE6lDj1SPYW_1THefR0z/file# [following]
# --2021-03-09 15:52:54--  https://ucc0e233fc73d9a328f1d83de4e8.dl.dropboxusercontent.com/cd/0/inline/BKUdwBSrDWjwvcwRjmVlC3KBAPcy0u6psPBfhpV6bpigPaODpUcVySVOyoX2zpeFaUqpedj18zYWwze0hy0-k5tbjYaglbHzwo8jP9AIZ7wtbfG0hrxWGa6M0Aj7fgmbnQcnoE6lDj1SPYW_1THefR0z/file
# Resolving ucc0e233fc73d9a328f1d83de4e8.dl.dropboxusercontent.com (ucc0e233fc73d9a328f1d83de4e8.dl.dropboxusercontent.com)... 162.125.82.15, 2620:100:6032:15::a27d:520f
# Connecting to ucc0e233fc73d9a328f1d83de4e8.dl.dropboxusercontent.com (ucc0e233fc73d9a328f1d83de4e8.dl.dropboxusercontent.com)|162.125.82.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BKWPgncHrzCSsPrH01Y-d3QG__nUZ4f8uQWbSqxc6Hg8kvy3vBfK0IC3nE1FXTnrPWKdTPJAtQYAxbCIX3x3Wqfww7zjMSq_XiPczWObdcMt5xRQk2ntvd5xZZws-cKM7bnl4mmb86hpHz9x7ndSumU3Dn4FN0f5_GLzV3FjR5uAeH4_2qN2rO7SUXlu4BVRWhi9kH5lcpFf1Dx2lGbVL3WyhD9Do7HsEDImbAhGoVZ5n1ZdmXiphORmp38F3vKWBMheEJ_pmneGBWd114X7a030hfdPpzq2FMLPJvnXH7Rj2-U3zqribLVfTHbfATIGSbkviyMZ-cIzNV3qQClzaf92O839CwCH2c2gDRT9DpJAKJFCqlOzog1HBf6OnShbEV4/file [following]
# --2021-03-09 15:52:55--  https://ucc0e233fc73d9a328f1d83de4e8.dl.dropboxusercontent.com/cd/0/inline2/BKWPgncHrzCSsPrH01Y-d3QG__nUZ4f8uQWbSqxc6Hg8kvy3vBfK0IC3nE1FXTnrPWKdTPJAtQYAxbCIX3x3Wqfww7zjMSq_XiPczWObdcMt5xRQk2ntvd5xZZws-cKM7bnl4mmb86hpHz9x7ndSumU3Dn4FN0f5_GLzV3FjR5uAeH4_2qN2rO7SUXlu4BVRWhi9kH5lcpFf1Dx2lGbVL3WyhD9Do7HsEDImbAhGoVZ5n1ZdmXiphORmp38F3vKWBMheEJ_pmneGBWd114X7a030hfdPpzq2FMLPJvnXH7Rj2-U3zqribLVfTHbfATIGSbkviyMZ-cIzNV3qQClzaf92O839CwCH2c2gDRT9DpJAKJFCqlOzog1HBf6OnShbEV4/file
# Reusing existing connection to ucc0e233fc73d9a328f1d83de4e8.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1222565663 (1.1G) [application/zip]
# Saving to: ‘BinaryDataset.zip?dl=0’
#
# BinaryDataset.zip?d 100%[===================>]   1.14G  16.5MB/s    in 79s
#
# 2021-03-09 15:54:14 (14.8 MB/s) - ‘BinaryDataset.zip?dl=0’ saved [1222565663/1222565663]

# %%
# !unzip /content/BinaryDataset.zip\?dl\=0 #Extracting the compressed dataset file

# %%
#Importing all the libraries required for preprocessing, training and evaluation of the model
from tensorflow import keras
from tensorflow.keras import preprocessing
from tensorflow.keras.preprocessing import image_dataset_from_directory #Importing Functions for image preprocessing from keras
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau #Importing Functions for early stopping and learning rate reduction
from sklearn.utils import class_weight #Importing functions for computing class weights from scikit learn class_weight module
from keras.utils import plot_model
from keras.preprocessing import image
from keras.layers import *
from keras.models import * #Importing the functions required for creating the model
import matplotlib.pyplot as plt #For plotting the training and validation loss and accuracy graphs
import numpy as np
import pandas as pd

# %%
#train_images_path = "DatasetBinaryClassification/Train"
#validation_images_path = "DatasetBinaryClassification/Validation"
#test_images_path = "DatasetBinaryClassification/Test"
train_images_path = "BinaryDataset/Train"
validation_images_path = "BinaryDataset/Validation"
test_images_path = "BinaryDataset/Test"
image_height = 256
image_width = 256

# %%
#Training data augmentation before feeding it to the CNN model
train_datagen = image.ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,  #flipping will add more variations to the data and it will help fight overfitting as welll
    )

#Preprocessing the training dataset
train_dataset= train_datagen.flow_from_directory(
    train_images_path,
    target_size = (image_height,image_width), 
    batch_size = 32,
    color_mode="grayscale",
    class_mode = "binary", #class mode is binary for binary classification
    shuffle = True,
    seed =50
    )

inp_shape= train_dataset.image_shape
print("Input Shape: " , inp_shape)
print("Class Labels: ", train_dataset.class_indices)
# Out:
# Found 3108 images belonging to 2 classes.
# Input Shape:  (256, 256, 1)
# Class Labels:  {'COVID': 0, 'Non-COVID': 1}

# %%
validation_datagen = image.ImageDataGenerator(rescale = 1./255) #Rescaling the validation images 

#Preprocessing the validation dataset
validation_dataset = validation_datagen.flow_from_directory(
    validation_images_path,
    target_size = (image_height,image_width),
    batch_size = 32,
    color_mode = "grayscale" ,
    class_mode = "binary", 
    shuffle = True,
    seed =40
    )
# Out:
# Found 388 images belonging to 2 classes.

# %%
test_datagen = image.ImageDataGenerator(rescale = 1./255) #Rescaling the test images 

#Preprocessing the testing dataset
test_dataset = test_datagen.flow_from_directory(
    test_images_path,
    target_size = (image_height,image_width),
    batch_size = 32,
    color_mode = "grayscale" ,
    class_mode = "binary", 
    shuffle = True,
    seed =20
    )
# Out:
# Found 312 images belonging to 2 classes.

# %%
#Visualization of Preprocessed Data
plt.figure(figsize=(20, 10))
for i in range(0, 10):
    plt.subplot(2, 5, i+1)
    for X_batch, Y_batch in train_dataset:
        image = X_batch[0]        
        dic = {0: 'COVID', 1:'Non-COVID'} 
        plt.title(dic.get(Y_batch[0])) #to get index of the image label
        plt.axis('on')
        plt.imshow(np.squeeze(image),cmap='gray',interpolation='nearest')
        break
plt.tight_layout()
plt.show()

# %%
#CNN Sequential Model using Keras
#Multiple layers with different number of filters
#Layered architecture with 4 Convolutional Layers
seqmodel = Sequential()

seqmodel.add(Conv2D(32,
                 kernel_size = (3,3),
                 activation = 'relu',
                 input_shape =inp_shape)) 

seqmodel.add(Conv2D(64,
                 kernel_size = (3,3), 
                 activation = 'relu'))

seqmodel.add(MaxPooling2D(pool_size=(2,2)))

seqmodel.add(Dropout(0.25)) #to prevent overfitting

seqmodel.add(Conv2D(64,
                 kernel_size = (3,3),
                 activation='relu'))

seqmodel.add(MaxPooling2D(pool_size=(2,2)))

seqmodel.add(Dropout(0.25))

seqmodel.add(Conv2D(128,
                 kernel_size = (3,3), 
                 activation='relu'))

seqmodel.add(MaxPooling2D(pool_size=(2,2)))

seqmodel.add(Dropout(0.25))

seqmodel.add(Flatten())

seqmodel.add(Dense(64,activation='relu')) 

seqmodel.add(Dropout(0.5)) #changed dropout value from 0.25 to 0.5 to further prevent overfitting

seqmodel.add(Dense(1,activation='sigmoid')) #activation function is sigmoid for binary classification 


seqmodel.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) #configuring the learning process 
                                                                                     #using binary crossentropy

seqmodel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 254, 254, 32)      320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 252, 252, 64)      18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 126, 126, 64)      0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 126, 126, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 124, 124, 64)      36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 60, 60, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30, 30, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 115200)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                7372864
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 7,502,529
# Trainable params: 7,502,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(seqmodel.input.shape)
plot_model(seqmodel,show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True)
# Out:
# (None, 256, 256, 1)

# %%
STEP_SIZE_TRAIN=train_dataset.n//train_dataset.batch_size
STEP_SIZE_VALID=validation_dataset.n//validation_dataset.batch_size
print(STEP_SIZE_TRAIN)
print(STEP_SIZE_VALID)
# Out:
# 97
# 12

# %%
#Defining functions for early stopping and adjusting the learning rate during model training 
earlyStop = EarlyStopping(monitor="val_loss", mode="min", patience=4, verbose= 1)
learningRateReduce = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.4, min_lr=0.0000001)
callbacksList = [ earlyStop, learningRateReduce]

# %%
#Assigning class weights using the compute class weights function
classWeights = class_weight.compute_class_weight('balanced', np.unique(train_dataset.classes), train_dataset.classes)
classWeightsDict = dict(enumerate(classWeights))
print("The class weights to be assigned to each label are:", classWeightsDict)
# Out:
# The class weights to be assigned to each label are: {0: 1.61875, 1: 0.723463687150838}

# %%
hist = seqmodel.fit(
    train_dataset, 
    steps_per_epoch = STEP_SIZE_TRAIN, 
    epochs=100,
    validation_data = validation_dataset,
    validation_steps = STEP_SIZE_VALID,
    class_weight = classWeightsDict,
    callbacks=callbacksList
    )
# Out:
# Epoch 1/100
# 97/97 [==============================] - 66s 669ms/step - loss: 0.5682 - accuracy: 0.7622 - val_loss: 0.1684 - val_accuracy: 0.9531
# Epoch 2/100
# 97/97 [==============================] - 65s 667ms/step - loss: 0.2189 - accuracy: 0.9209 - val_loss: 0.1172 - val_accuracy: 0.9635
# Epoch 3/100
# 97/97 [==============================] - 65s 665ms/step - loss: 0.1858 - accuracy: 0.9307 - val_loss: 0.0984 - val_accuracy: 0.9661
# Epoch 4/100
# 97/97 [==============================] - 64s 662ms/step - loss: 0.1826 - accuracy: 0.9428 - val_loss: 0.0935 - val_accuracy: 0.9661
# Epoch 5/100
# 97/97 [==============================] - 64s 661ms/step - loss: 0.1846 - accuracy: 0.9433 - val_loss: 0.1417 - val_accuracy: 0.9609
# Epoch 6/100
# 97/97 [==============================] - 64s 659ms/step - loss: 0.1562 - accuracy: 0.9429 - val_loss: 0.1006 - val_accuracy: 0.9661
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# Epoch 7/100
# 97/97 [==============================] - 64s 657ms/step - loss: 0.1352 - accuracy: 0.9524 - val_loss: 0.1036 - val_accuracy: 0.9661
# Epoch 8/100
# 97/97 [==============================] - 65s 669ms/step - loss: 0.1381 - accuracy: 0.9572 - val_loss: 0.0904 - val_accuracy: 0.9714
# Epoch 9/100
# 97/97 [==============================] - 65s 671ms/step - loss: 0.1213 - accuracy: 0.9569 - val_loss: 0.0849 - val_accuracy: 0.9714
# Epoch 10/100
# 97/97 [==============================] - 65s 667ms/step - loss: 0.1131 - accuracy: 0.9578 - val_loss: 0.0898 - val_accuracy: 0.9714
# Epoch 11/100
# 97/97 [==============================] - 65s 669ms/step - loss: 0.1049 - accuracy: 0.9649 - val_loss: 0.0819 - val_accuracy: 0.9688
# Epoch 12/100
# 97/97 [==============================] - 64s 662ms/step - loss: 0.1395 - accuracy: 0.9562 - val_loss: 0.0895 - val_accuracy: 0.9714
# Epoch 13/100
# 97/97 [==============================] - 64s 658ms/step - loss: 0.1299 - accuracy: 0.9559 - val_loss: 0.0795 - val_accuracy: 0.9740
# Epoch 14/100
# 97/97 [==============================] - 64s 659ms/step - loss: 0.1153 - accuracy: 0.9592 - val_loss: 0.1005 - val_accuracy: 0.9661
# Epoch 15/100
# 97/97 [==============================] - 65s 666ms/step - loss: 0.1214 - accuracy: 0.9595 - val_loss: 0.0712 - val_accuracy: 0.9766
# Epoch 16/100
# 97/97 [==============================] - 65s 671ms/step - loss: 0.1227 - accuracy: 0.9587 - val_loss: 0.0642 - val_accuracy: 0.9740
# Epoch 17/100
# 97/97 [==============================] - 65s 670ms/step - loss: 0.0969 - accuracy: 0.9669 - val_loss: 0.0641 - val_accuracy: 0.9766
# Epoch 18/100
# 97/97 [==============================] - 65s 670ms/step - loss: 0.1170 - accuracy: 0.9632 - val_loss: 0.0618 - val_accuracy: 0.9740
# Epoch 19/100
# 97/97 [==============================] - 66s 674ms/step - loss: 0.1055 - accuracy: 0.9678 - val_loss: 0.0614 - val_accuracy: 0.9740
# Epoch 20/100
# 97/97 [==============================] - 65s 667ms/step - loss: 0.1013 - accuracy: 0.9654 - val_loss: 0.0661 - val_accuracy: 0.9766
# Epoch 21/100
# 97/97 [==============================] - 65s 670ms/step - loss: 0.1008 - accuracy: 0.9690 - val_loss: 0.0614 - val_accuracy: 0.9844
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# Epoch 22/100
# 97/97 [==============================] - 65s 671ms/step - loss: 0.0904 - accuracy: 0.9671 - val_loss: 0.0611 - val_accuracy: 0.9818
# Epoch 23/100
# 97/97 [==============================] - 66s 673ms/step - loss: 0.0833 - accuracy: 0.9658 - val_loss: 0.0642 - val_accuracy: 0.9818
# Epoch 24/100
# 97/97 [==============================] - 66s 674ms/step - loss: 0.0819 - accuracy: 0.9766 - val_loss: 0.0563 - val_accuracy: 0.9792
# Epoch 25/100
# 97/97 [==============================] - 64s 662ms/step - loss: 0.0753 - accuracy: 0.9759 - val_loss: 0.0528 - val_accuracy: 0.9818
# Epoch 26/100
# 97/97 [==============================] - 65s 672ms/step - loss: 0.0801 - accuracy: 0.9710 - val_loss: 0.0584 - val_accuracy: 0.9792
# Epoch 27/100
# 97/97 [==============================] - 66s 675ms/step - loss: 0.0753 - accuracy: 0.9727 - val_loss: 0.0543 - val_accuracy: 0.9792
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# Epoch 28/100
# 97/97 [==============================] - 65s 671ms/step - loss: 0.0783 - accuracy: 0.9768 - val_loss: 0.0510 - val_accuracy: 0.9766
# Epoch 29/100
# 97/97 [==============================] - 65s 672ms/step - loss: 0.0669 - accuracy: 0.9762 - val_loss: 0.0495 - val_accuracy: 0.9844
# Epoch 30/100
# 97/97 [==============================] - 65s 670ms/step - loss: 0.0800 - accuracy: 0.9753 - val_loss: 0.0470 - val_accuracy: 0.9844
# Epoch 31/100
# 97/97 [==============================] - 65s 673ms/step - loss: 0.0662 - accuracy: 0.9795 - val_loss: 0.0486 - val_accuracy: 0.9818
# Epoch 32/100
# 97/97 [==============================] - 66s 674ms/step - loss: 0.0511 - accuracy: 0.9812 - val_loss: 0.0489 - val_accuracy: 0.9818
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# Epoch 33/100
# 97/97 [==============================] - 67s 686ms/step - loss: 0.0695 - accuracy: 0.9730 - val_loss: 0.0486 - val_accuracy: 0.9818
# Epoch 34/100
# 97/97 [==============================] - 66s 675ms/step - loss: 0.0659 - accuracy: 0.9795 - val_loss: 0.0492 - val_accuracy: 0.9818
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# Epoch 00034: early stopping

# %%
seqmodel.save('SequentialModel_Binary_Final.h5') #Saving the model
#seqmodel = load_model('/content/SequentialModel_Binary_Final.h5') #for loading the model

# %%
#Plotting the graph for training and validation loss
plt.locator_params(axis='x', integer=True, tight=True) #To ensure no. of epochs is shown as integers
plt.plot(hist.history['loss'],'r',label='training loss')
plt.plot(hist.history['val_loss'],label='validation loss')
plt.xlabel('Number of epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Plotting the graph for training and validation accuracy
plt.locator_params(axis='x', integer=True, tight=True) 
plt.plot(hist.history['accuracy'],'r',label='training accuracy')
plt.plot(hist.history['val_accuracy'],label='validation accuracy')
plt.xlabel('Number of epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Plotting the graph for learning rate
plt.locator_params(axis='x', integer=True, tight=True) 
plt.plot(hist.history['lr'],label='learning rate')
plt.xlabel('Number of epochs')
plt.ylabel('Learning Rate')
plt.legend()
plt.show()

# %%
testingAccuracy = seqmodel.evaluate(test_dataset) #Evaluating the model on the testing dataset
print("The Sequential Model for binary classification has a testing accuracy of:", testingAccuracy[1]*100, "%")
# Out:
# 10/10 [==============================] - 4s 410ms/step - loss: 0.0772 - accuracy: 0.9712
# The Sequential Model for binary classification has a testing accuracy of: 97.11538553237915 %
